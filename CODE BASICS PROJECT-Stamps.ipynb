# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_stamp =pd.read_csv(r"C:\Users\venu\Downloads\C7 Input Files_\C7 Input Files_\dataset\fact_stamps.csv")
df_stamp
# Out:
#      dist_code       month  documents_registered_cnt  \
# 0         14_1  2019-04-01                      4533
# 1         17_3  2019-04-01                      4151
# 2         20_3  2019-04-01                      2116
# 3         21_5  2019-04-01                      1089
# 4         23_1  2019-04-01                      6133
# ...        ...         ...                       ...
# 1499      20_4  2023-03-01                      1510
# 1500      14_5  2023-03-01                       980
# 1501      21_1  2023-03-01                      4321
# 1502      22_2  2023-03-01                      1255
# 1503      23_1  2023-03-01                      5806
#
#       documents_registered_rev  estamps_challans_cnt  estamps_challans_rev
# 0                     59236363                     0                     0
# 1                     41508762                     0                     0
# 2                     23674170                     0                     0
# ...

# %%
df1_dist = pd.read_csv(r"C:\Users\venu\Downloads\C7 Input Files_\C7 Input Files_\dataset\dim_districts.csv")
df1_dist
# Out:
#    dist_code                 district
# 0       19_1                 Adilabad
# 1       22_2     Bhadradri Kothagudem
# 2       21_1              Hanumakonda
# 3       16_1                Hyderabad
# 4       20_2                  Jagtial
# 5       21_3                  Jangoan
# 6       21_7  Jayashankar Bhupalpally
# 7       14_2         Jogulamba Gadwal
# 8       18_2                Kamareddy
# 9       20_1               Karimnagar
# 10      22_1                  Khammam
# 11      19_4    Kumurambheem Asifabad
# 12      21_5              Mahabubabad
# 13      14_1             Mahabubnagar
# 14      19_3               Mancherial
# 15      17_1                    Medak
# 16      15_2       Medchal_Malkajgiri
# 17      21_6                   Mulugu
# 18      14_3             Nagarkurnool
# 19      23_1                 Nalgonda
# 20      14_5               Narayanpet
# 21      19_2                   Nirmal
# 22      18_1                Nizamabad
# 23      20_4               Peddapalli
# ...

# %%
df_date = pd.read_csv(r"C:\Users\venu\Downloads\C7 Input Files_\C7 Input Files_\dataset\dim_date.csv")
df_date
# Out:
#          month  Mmm quarter  fiscal_year
# 0   2019-04-01  Apr      Q1         2019
# 1   2019-05-01  May      Q1         2019
# 2   2019-06-01  Jun      Q1         2019
# 3   2019-07-01  Jul      Q2         2019
# 4   2019-08-01  Aug      Q2         2019
# 5   2019-09-01  Sep      Q2         2019
# 6   2019-10-01  Oct      Q3         2019
# 7   2019-11-01  Nov      Q3         2019
# 8   2019-12-01  Dec      Q3         2019
# 9   2020-01-01  Jan      Q4         2019
# 10  2020-02-01  Feb      Q4         2019
# 11  2020-03-01  Mar      Q4         2019
# 12  2020-04-01  Apr      Q1         2020
# 13  2020-05-01  May      Q1         2020
# 14  2020-06-01  Jun      Q1         2020
# 15  2020-07-01  Jul      Q2         2020
# 16  2020-08-01  Aug      Q2         2020
# 17  2020-09-01  Sep      Q2         2020
# 18  2020-10-01  Oct      Q3         2020
# 19  2020-11-01  Nov      Q3         2020
# 20  2020-12-01  Dec      Q3         2020
# 21  2021-01-01  Jan      Q4         2020
# ...

# %%
df_merge1 = pd.merge(df1_dist,df_stamp,on = "dist_code")
df_merge1
# Out:
#      dist_code             district       month  documents_registered_cnt  \
# 0         19_1             Adilabad  2019-04-01                      1043
# 1         19_1             Adilabad  2019-05-01                      1092
# 2         19_1             Adilabad  2019-06-01                       824
# 3         19_1             Adilabad  2019-07-01                      1186
# 4         19_1             Adilabad  2019-08-01                      1124
# ...        ...                  ...         ...                       ...
# 1499      23_3  Yadadri Bhuvanagiri  2022-11-01                      5334
# 1500      23_3  Yadadri Bhuvanagiri  2022-12-01                      5176
# 1501      23_3  Yadadri Bhuvanagiri  2023-01-01                      4676
# 1502      23_3  Yadadri Bhuvanagiri  2023-02-01                      4932
# 1503      23_3  Yadadri Bhuvanagiri  2023-03-01                      5308
#
#       documents_registered_rev  estamps_challans_cnt  estamps_challans_rev
# ...

# %%
df  = pd.merge(df_merge1,df_date,on = "month")
df
# Out:
#      dist_code              district       month  documents_registered_cnt  \
# 0         19_1              Adilabad  2019-04-01                      1043
# 1         22_2  Bhadradri Kothagudem  2019-04-01                       542
# 2         21_1           Hanumakonda  2019-04-01                      4186
# 3         16_1             Hyderabad  2019-04-01                      5268
# 4         20_2               Jagtial  2019-04-01                      1943
# ...        ...                   ...         ...                       ...
# 1499      23_2              Suryapet  2023-03-01                      3296
# 1500      15_3             Vikarabad  2023-03-01                      1520
# 1501      14_4            Wanaparthy  2023-03-01                      1833
# 1502      21_2              Warangal  2023-03-01                      1020
# 1503      23_3   Yadadri Bhuvanagiri  2023-03-01                      5308
#
# ...

# %%
df.head(10)
# Out:
#   dist_code              district       month  documents_registered_cnt  \
# 0      19_1              Adilabad  2019-04-01                      1043
# 1      22_2  Bhadradri Kothagudem  2019-04-01                       542
# 2      21_1           Hanumakonda  2019-04-01                      4186
# 3      16_1             Hyderabad  2019-04-01                      5268
# 4      20_2               Jagtial  2019-04-01                      1943
# 5      21_3               Jangoan  2019-04-01                      2372
# 6      14_2      Jogulamba Gadwal  2019-04-01                      2074
# 7      18_2             Kamareddy  2019-04-01                      2876
# 8      20_1            Karimnagar  2019-04-01                      2748
# 9      22_1               Khammam  2019-04-01                      4088
#
#    documents_registered_rev  estamps_challans_cnt  estamps_challans_rev  Mmm  \
# 0                  12672655                     0                     0  Apr
# ...

# %%
df1 = df.groupby("district")["documents_registered_rev"].sum().reset_index()
df1
# Out:
#                  district  documents_registered_rev
# 0                Adilabad                1066971491
# 1    Bhadradri Kothagudem                 824712666
# 2             Hanumakonda                7927494100
# 3               Hyderabad               38396743983
# 4                 Jagtial                1666081307
# 5                 Jangoan                1329898858
# 6        Jogulamba Gadwal                 978779682
# 7               Kamareddy                1396196267
# 8              Karimnagar                4024475054
# 9                 Khammam                5606141586
# 10  Kumurambheem Asifabad                 227462583
# 11            Mahabubabad                1058624771
# 12           Mahabubnagar                3186731550
# 13             Mancherial                1668092668
# 14                  Medak                1765752735
# 15     Medchal_Malkajgiri               64071382839
# 16                 Mulugu                 515528121
# ...

# %%
df1.sort_values("documents_registered_rev",ignore_index=True,ascending=False,inplace=True)

# %%
df1
# Out:
#                  district  documents_registered_rev
# 0              Rangareddy              108198682809
# 1      Medchal_Malkajgiri               64071382839
# 2               Hyderabad               38396743983
# 3              Sangareddy               22024502771
# 4             Hanumakonda                7927494100
# 5     Yadadri Bhuvanagiri                5973744502
# 6                 Khammam                5606141586
# 7                Nalgonda                4521634367
# 8               Nizamabad                4046937361
# 9              Karimnagar                4024475054
# 10           Mahabubnagar                3186731550
# 11               Suryapet                2902358766
# 12               Siddipet                2625072577
# 13                  Medak                1765752735
# 14             Peddapalli                1740644457
# 15             Mancherial                1668092668
# 16                Jagtial                1666081307
# ...

# %%
df1.head()
# Out:
#              district  documents_registered_rev
# 0          Rangareddy              108198682809
# 1  Medchal_Malkajgiri               64071382839
# 2           Hyderabad               38396743983
# 3          Sangareddy               22024502771
# 4         Hanumakonda                7927494100

# %% [markdown]
# ## 2nd Question

# %%
df
# Out:
#      dist_code              district       month  documents_registered_cnt  \
# 0         19_1              Adilabad  2019-04-01                      1043
# 1         22_2  Bhadradri Kothagudem  2019-04-01                       542
# 2         21_1           Hanumakonda  2019-04-01                      4186
# 3         16_1             Hyderabad  2019-04-01                      5268
# 4         20_2               Jagtial  2019-04-01                      1943
# ...        ...                   ...         ...                       ...
# 1499      23_2              Suryapet  2023-03-01                      3296
# 1500      15_3             Vikarabad  2023-03-01                      1520
# 1501      14_4            Wanaparthy  2023-03-01                      1833
# 1502      21_2              Warangal  2023-03-01                      1020
# 1503      23_3   Yadadri Bhuvanagiri  2023-03-01                      5308
#
# ...

# %%
df2 = df[df['fiscal_year']==2022]
df2
# Out:
#      dist_code              district       month  documents_registered_cnt  \
# 1120      19_1              Adilabad  2022-04-01                       762
# 1121      22_2  Bhadradri Kothagudem  2022-04-01                      1079
# 1122      21_1           Hanumakonda  2022-04-01                      4459
# 1123      16_1             Hyderabad  2022-04-01                      4771
# 1124      20_2               Jagtial  2022-04-01                      1366
# ...        ...                   ...         ...                       ...
# 1499      23_2              Suryapet  2023-03-01                      3296
# 1500      15_3             Vikarabad  2023-03-01                      1520
# 1501      14_4            Wanaparthy  2023-03-01                      1833
# 1502      21_2              Warangal  2023-03-01                      1020
# 1503      23_3   Yadadri Bhuvanagiri  2023-03-01                      5308
#
# ...

# %%
df3 = df2.groupby("district")[["documents_registered_rev","estamps_challans_rev"]].sum().reset_index()
df3                                  
#when we using double keys so we need to use double list
# Out:
#                  district  documents_registered_rev  estamps_challans_rev
# 0                Adilabad                 396840845             390406044
# 1    Bhadradri Kothagudem                 292643450             286343125
# 2             Hanumakonda                2817238587            2846856844
# 3               Hyderabad               14266012441           14374315032
# 4                 Jagtial                 628898536             635617022
# 5                 Jangoan                 473726459             485770112
# 6        Jogulamba Gadwal                 328969228             331919414
# 7               Kamareddy                 471629404             479194188
# 8              Karimnagar                1550449161            1555554043
# 9                 Khammam                1971647539            2002220314
# 10  Kumurambheem Asifabad                  75231587              75125612
# 11            Mahabubabad                 401471602             402178710
# ...

# %%
df3["add_revenue"]=df3['documents_registered_rev'] + df3['estamps_challans_rev']

# %%
df3
# Out:
#                  district  documents_registered_rev  estamps_challans_rev  \
# 0                Adilabad                 396840845             390406044
# 1    Bhadradri Kothagudem                 292643450             286343125
# 2             Hanumakonda                2817238587            2846856844
# 3               Hyderabad               14266012441           14374315032
# 4                 Jagtial                 628898536             635617022
# 5                 Jangoan                 473726459             485770112
# 6        Jogulamba Gadwal                 328969228             331919414
# 7               Kamareddy                 471629404             479194188
# 8              Karimnagar                1550449161            1555554043
# 9                 Khammam                1971647539            2002220314
# 10  Kumurambheem Asifabad                  75231587              75125612
# 11            Mahabubabad                 401471602             402178710
# ...

# %%
df3.sort_values("add_revenue",ignore_index=True,ascending=False,inplace=True)

# %%
df3
# Out:
#                  district  documents_registered_rev  estamps_challans_rev  \
# 0              Rangareddy               37697750946           38349357618
# 1      Medchal_Malkajgiri               24043523530           23596183308
# 2               Hyderabad               14266012441           14374315032
# 3              Sangareddy                8273200321            8259605302
# 4             Hanumakonda                2817238587            2846856844
# 5     Yadadri Bhuvanagiri                2167480603            2185270667
# 6                 Khammam                1971647539            2002220314
# 7              Karimnagar                1550449161            1555554043
# 8               Nizamabad                1441666957            1449452877
# 9                Nalgonda                1370570095            1378801930
# 10           Mahabubnagar                1066013551            1081759351
# 11               Suryapet                1025672569            1025231495
# ...

# %%
df3.head()
# Out:
#              district  documents_registered_rev  estamps_challans_rev  \
# 0          Rangareddy               37697750946           38349357618
# 1  Medchal_Malkajgiri               24043523530           23596183308
# 2           Hyderabad               14266012441           14374315032
# 3          Sangareddy                8273200321            8259605302
# 4         Hanumakonda                2817238587            2846856844
#
#    add_revenue
# 0  76047108564
# 1  47639706838
# 2  28640327473
# 3  16532805623
# 4   5664095431

# %% [markdown]
# ## 3rd Question

# %%
df
# Out:
#      dist_code              district       month  documents_registered_cnt  \
# 0         19_1              Adilabad  2019-04-01                      1043
# 1         22_2  Bhadradri Kothagudem  2019-04-01                       542
# 2         21_1           Hanumakonda  2019-04-01                      4186
# 3         16_1             Hyderabad  2019-04-01                      5268
# 4         20_2               Jagtial  2019-04-01                      1943
# ...        ...                   ...         ...                       ...
# 1499      23_2              Suryapet  2023-03-01                      3296
# 1500      15_3             Vikarabad  2023-03-01                      1520
# 1501      14_4            Wanaparthy  2023-03-01                      1833
# 1502      21_2              Warangal  2023-03-01                      1020
# 1503      23_3   Yadadri Bhuvanagiri  2023-03-01                      5308
#
# ...

# %%
df4=df[df["estamps_challans_cnt"]>0]

# %%
df4
# Out:
#      dist_code              district       month  documents_registered_cnt  \
# 640       19_1              Adilabad  2020-12-01                       371
# 641       22_2  Bhadradri Kothagudem  2020-12-01                       270
# 642       21_1           Hanumakonda  2020-12-01                      1775
# 643       16_1             Hyderabad  2020-12-01                      2997
# 644       20_2               Jagtial  2020-12-01                       344
# ...        ...                   ...         ...                       ...
# 1499      23_2              Suryapet  2023-03-01                      3296
# 1500      15_3             Vikarabad  2023-03-01                      1520
# 1501      14_4            Wanaparthy  2023-03-01                      1833
# 1502      21_2              Warangal  2023-03-01                      1020
# 1503      23_3   Yadadri Bhuvanagiri  2023-03-01                      5308
#
# ...

# %%
df5=df4.groupby("district")[["documents_registered_cnt","estamps_challans_cnt"]].sum().reset_index()

# %%
df5.sort_values("estamps_challans_cnt",ascending=False,ignore_index=True,inplace=True)

# %%
df5
# Out:
#                  district  documents_registered_cnt  estamps_challans_cnt
# 0              Rangareddy                    549145                581231
# 1      Medchal_Malkajgiri                    379488                399643
# 2              Sangareddy                    161334                170957
# 3               Hyderabad                    139793                151400
# 4     Yadadri Bhuvanagiri                    143797                150415
# 5                Nalgonda                    126203                130049
# 6             Hanumakonda                    110642                119822
# 7               Nizamabad                    112555                119002
# 8                 Khammam                    102500                107924
# 9                Siddipet                     91348                 88779
# 10               Suryapet                     78973                 82779
# 11             Karimnagar                     77490                 79880
# ...

# %% [markdown]
# ## 4th Question

# %%
df
# Out:
#      dist_code              district       month  documents_registered_cnt  \
# 0         19_1              Adilabad  2019-04-01                      1043
# 1         22_2  Bhadradri Kothagudem  2019-04-01                       542
# 2         21_1           Hanumakonda  2019-04-01                      4186
# 3         16_1             Hyderabad  2019-04-01                      5268
# 4         20_2               Jagtial  2019-04-01                      1943
# ...        ...                   ...         ...                       ...
# 1499      23_2              Suryapet  2023-03-01                      3296
# 1500      15_3             Vikarabad  2023-03-01                      1520
# 1501      14_4            Wanaparthy  2023-03-01                      1833
# 1502      21_2              Warangal  2023-03-01                      1020
# 1503      23_3   Yadadri Bhuvanagiri  2023-03-01                      5308
#
# ...

# %%
df6 = df[df["fiscal_year"] >= 2021]
df6
# Out:
#      dist_code              district       month  documents_registered_cnt  \
# 768       19_1              Adilabad  2021-04-01                       959
# 769       22_2  Bhadradri Kothagudem  2021-04-01                       818
# 770       21_1           Hanumakonda  2021-04-01                      4150
# 771       16_1             Hyderabad  2021-04-01                      4406
# 772       20_2               Jagtial  2021-04-01                      1300
# ...        ...                   ...         ...                       ...
# 1499      23_2              Suryapet  2023-03-01                      3296
# 1500      15_3             Vikarabad  2023-03-01                      1520
# 1501      14_4            Wanaparthy  2023-03-01                      1833
# 1502      21_2              Warangal  2023-03-01                      1020
# 1503      23_3   Yadadri Bhuvanagiri  2023-03-01                      5308
#
# ...

# %%
df7 = df6.groupby("district")[["documents_registered_rev","estamps_challans_rev"]].sum().reset_index()
df7
# Out:
#                  district  documents_registered_rev  estamps_challans_rev
# 0                Adilabad                 720926384             723003081
# 1    Bhadradri Kothagudem                 534180926             540722552
# 2             Hanumakonda                4895047216            4959670232
# 3               Hyderabad               24977902615           25267992981
# 4                 Jagtial                1069526503            1079332319
# 5                 Jangoan                 733613593             747428965
# 6        Jogulamba Gadwal                 601645197             603996030
# 7               Kamareddy                 851578792             859661958
# 8              Karimnagar                2619104284            2633977624
# 9                 Khammam                3615169800            3646844602
# 10  Kumurambheem Asifabad                 136257292             133420327
# 11            Mahabubabad                 658996063             666572041
# ...

# %%
df7["total_rev"] = df7["documents_registered_rev"] + df7["estamps_challans_rev"]
df7
# Out:
#                  district  documents_registered_rev  estamps_challans_rev  \
# 0                Adilabad                 720926384             723003081
# 1    Bhadradri Kothagudem                 534180926             540722552
# 2             Hanumakonda                4895047216            4959670232
# 3               Hyderabad               24977902615           25267992981
# 4                 Jagtial                1069526503            1079332319
# 5                 Jangoan                 733613593             747428965
# 6        Jogulamba Gadwal                 601645197             603996030
# 7               Kamareddy                 851578792             859661958
# 8              Karimnagar                2619104284            2633977624
# 9                 Khammam                3615169800            3646844602
# 10  Kumurambheem Asifabad                 136257292             133420327
# 11            Mahabubabad                 658996063             666572041
# ...

# %%
df7.sort_values("total_rev",ascending = False,ignore_index=True,inplace=True)

# %%
df7
# Out:
#                  district  documents_registered_rev  estamps_challans_rev  \
# 0              Rangareddy               69563226936           70682297387
# 1      Medchal_Malkajgiri               42244415731           42344075412
# 2               Hyderabad               24977902615           25267992981
# 3              Sangareddy               14617585438           14782041561
# 4             Hanumakonda                4895047216            4959670232
# 5     Yadadri Bhuvanagiri                3787070881            3801870232
# 6                 Khammam                3615169800            3646844602
# 7              Karimnagar                2619104284            2633977624
# 8               Nizamabad                2592723703            2614662871
# 9                Nalgonda                2586636489            2600080824
# 10           Mahabubnagar                1960011646            1981371785
# 11               Suryapet                1802987342            1818082431
# ...
