# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_transport = pd.read_csv(r"C:\Users\venu\Downloads\C7 Input Files_\C7 Input Files_\dataset\fact_transport.csv")
df_transport
# Out:
#      dist_code       month  fuel_type_petrol  fuel_type_diesel  \
# 0         15_1  2019-04-01             17910              3011
# 1         18_2  2019-04-01              3066               306
# 2         20_3  2019-04-01              1577               215
# 3         21_3  2019-04-01              1961               281
# 4         21_7  2019-04-01              1552               309
# ...        ...         ...               ...               ...
# 1435      16_1  2023-03-01             24112              2169
# 1436      14_4  2023-03-01               996               286
# 1437      20_3  2023-03-01               886               183
# 1438      23_3  2023-03-01              1659               472
# 1439      18_2  2023-03-01              1767               239
#
#       fuel_type_electric  fuel_type_others  vehicleClass_MotorCycle  \
# 0                     76                22                    15308
# 1                      6                 0                     2995
# ...

# %%
df1_dist = pd.read_csv(r"C:\Users\venu\Downloads\C7 Input Files_\C7 Input Files_\dataset\dim_districts.csv")
df1_dist
# Out:
#    dist_code                 district
# 0       19_1                 Adilabad
# 1       22_2     Bhadradri Kothagudem
# 2       21_1              Hanumakonda
# 3       16_1                Hyderabad
# 4       20_2                  Jagtial
# 5       21_3                  Jangoan
# 6       21_7  Jayashankar Bhupalpally
# 7       14_2         Jogulamba Gadwal
# 8       18_2                Kamareddy
# 9       20_1               Karimnagar
# 10      22_1                  Khammam
# 11      19_4    Kumurambheem Asifabad
# 12      21_5              Mahabubabad
# 13      14_1             Mahabubnagar
# 14      19_3               Mancherial
# 15      17_1                    Medak
# 16      15_2       Medchal_Malkajgiri
# 17      21_6                   Mulugu
# 18      14_3             Nagarkurnool
# 19      23_1                 Nalgonda
# 20      14_5               Narayanpet
# 21      19_2                   Nirmal
# 22      18_1                Nizamabad
# 23      20_4               Peddapalli
# ...

# %%
df_date = pd.read_csv(r"C:\Users\venu\Downloads\C7 Input Files_\C7 Input Files_\dataset\dim_date.csv")
df_date
# Out:
#          month  Mmm quarter  fiscal_year
# 0   2019-04-01  Apr      Q1         2019
# 1   2019-05-01  May      Q1         2019
# 2   2019-06-01  Jun      Q1         2019
# 3   2019-07-01  Jul      Q2         2019
# 4   2019-08-01  Aug      Q2         2019
# 5   2019-09-01  Sep      Q2         2019
# 6   2019-10-01  Oct      Q3         2019
# 7   2019-11-01  Nov      Q3         2019
# 8   2019-12-01  Dec      Q3         2019
# 9   2020-01-01  Jan      Q4         2019
# 10  2020-02-01  Feb      Q4         2019
# 11  2020-03-01  Mar      Q4         2019
# 12  2020-04-01  Apr      Q1         2020
# 13  2020-05-01  May      Q1         2020
# 14  2020-06-01  Jun      Q1         2020
# 15  2020-07-01  Jul      Q2         2020
# 16  2020-08-01  Aug      Q2         2020
# 17  2020-09-01  Sep      Q2         2020
# 18  2020-10-01  Oct      Q3         2020
# 19  2020-11-01  Nov      Q3         2020
# 20  2020-12-01  Dec      Q3         2020
# 21  2021-01-01  Jan      Q4         2020
# ...

# %%
df_ = pd.merge(df1_dist,df_transport)

# %%
df = pd.merge(df_,df_date)
df
# Out:
#      dist_code              district       month  fuel_type_petrol  \
# 0         19_1              Adilabad  2019-04-01              1758
# 1         22_2  Bhadradri Kothagudem  2019-04-01              3527
# 2         16_1             Hyderabad  2019-04-01             24309
# 3         20_2               Jagtial  2019-04-01              2786
# 4         21_3               Jangoan  2019-04-01              1961
# ...        ...                   ...         ...               ...
# 1435      23_2              Suryapet  2023-03-01              2013
# 1436      15_3             Vikarabad  2023-03-01              3088
# 1437      14_4            Wanaparthy  2023-03-01               996
# 1438      21_2              Warangal  2023-03-01              1832
# 1439      23_3   Yadadri Bhuvanagiri  2023-03-01              1659
#
#       fuel_type_diesel  fuel_type_electric  fuel_type_others  \
# 0                  326                   0                 2
# ...

# %%
df.columns
# Out:
# Index(['dist_code', 'district', 'month', 'fuel_type_petrol',
#        'fuel_type_diesel', 'fuel_type_electric', 'fuel_type_others',
#        'vehicleClass_MotorCycle', 'vehicleClass_MotorCar',
#        'vehicleClass_AutoRickshaw', 'vehicleClass_Agriculture',
#        'vehicleClass_others', 'seatCapacity_1_to_3', 'seatCapacity_4_to_6',
#        'seatCapacity_above_6', 'Brand_new_vehicles', 'Pre-owned_vehicles',
#        'category_Non-Transport', 'category_Transport', 'Mmm', 'quarter',
#        'fiscal_year'],
#       dtype='object')

# %%
df8 =df.groupby("Mmm")[["vehicleClass_MotorCycle","vehicleClass_MotorCar","vehicleClass_others","vehicleClass_Agriculture","vehicleClass_AutoRickshaw"]].sum().reset_index()

# %%
df8["total"]=df8["vehicleClass_MotorCycle"]+df8["vehicleClass_MotorCar"] +df8["vehicleClass_others"]+df8["vehicleClass_Agriculture"]+df8["vehicleClass_AutoRickshaw"]

# %%
df8
# Out:
#     Mmm  vehicleClass_MotorCycle  vehicleClass_MotorCar  vehicleClass_others  \
# 0   Apr                   316395                  67232                29669
# 1   Aug                   417597                  94071                35848
# 2   Dec                   332438                 111522                38820
# 3   Feb                   384121                  81459                42454
# 4   Jan                   410226                  79140                44899
# 5   Jul                   407743                  83407                40797
# 6   Jun                   450740                  81528                45049
# 7   Mar                   417646                  99965                52339
# 8   May                   321903                  61589                33091
# 9   Nov                   439701                  81912                38093
# 10  Oct                   552577                 111044                46759
# ...

# %%
df8.corr()
# Out:
# C:\Users\venu\AppData\Local\Temp\ipykernel_8868\3190029978.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df8.corr()
#                            vehicleClass_MotorCycle  vehicleClass_MotorCar  \
# vehicleClass_MotorCycle                   1.000000               0.506578
# vehicleClass_MotorCar                     0.506578               1.000000
# vehicleClass_others                       0.624582               0.545381
# vehicleClass_Agriculture                  0.682842               0.248838
# vehicleClass_AutoRickshaw                 0.539101               0.642026
# total                                     0.979221               0.653331
#
#                            vehicleClass_others  vehicleClass_Agriculture  \
# vehicleClass_MotorCycle               0.624582                  0.682842
# ...

# %%
df
# Out:
#      dist_code              district       month  fuel_type_petrol  \
# 0         19_1              Adilabad  2019-04-01              1758
# 1         22_2  Bhadradri Kothagudem  2019-04-01              3527
# 2         16_1             Hyderabad  2019-04-01             24309
# 3         20_2               Jagtial  2019-04-01              2786
# 4         21_3               Jangoan  2019-04-01              1961
# ...        ...                   ...         ...               ...
# 1435      23_2              Suryapet  2023-03-01              2013
# 1436      15_3             Vikarabad  2023-03-01              3088
# 1437      14_4            Wanaparthy  2023-03-01               996
# 1438      21_2              Warangal  2023-03-01              1832
# 1439      23_3   Yadadri Bhuvanagiri  2023-03-01              1659
#
#       fuel_type_diesel  fuel_type_electric  fuel_type_others  \
# 0                  326                   0                 2
# ...

# %%
df9 =df[df["fiscal_year"] == 2022]
df9
# Out:
#      dist_code              district       month  fuel_type_petrol  \
# 1080      19_1              Adilabad  2022-04-01              1545
# 1081      22_2  Bhadradri Kothagudem  2022-04-01              2356
# 1082      16_1             Hyderabad  2022-04-01             20341
# 1083      20_2               Jagtial  2022-04-01              1691
# 1084      21_3               Jangoan  2022-04-01              1040
# ...        ...                   ...         ...               ...
# 1435      23_2              Suryapet  2023-03-01              2013
# 1436      15_3             Vikarabad  2023-03-01              3088
# 1437      14_4            Wanaparthy  2023-03-01               996
# 1438      21_2              Warangal  2023-03-01              1832
# 1439      23_3   Yadadri Bhuvanagiri  2023-03-01              1659
#
#       fuel_type_diesel  fuel_type_electric  fuel_type_others  \
# 1080               182                   8                 0
# ...

# %%
df10 = df9.groupby("district")[['vehicleClass_MotorCycle', 'vehicleClass_MotorCar',
       'vehicleClass_AutoRickshaw', 'vehicleClass_Agriculture',
       'vehicleClass_others']].sum().reset_index()

# %%
df9.columns
# Out:
# Index(['dist_code', 'district', 'month', 'fuel_type_petrol',
#        'fuel_type_diesel', 'fuel_type_electric', 'fuel_type_others',
#        'vehicleClass_MotorCycle', 'vehicleClass_MotorCar',
#        'vehicleClass_AutoRickshaw', 'vehicleClass_Agriculture',
#        'vehicleClass_others', 'seatCapacity_1_to_3', 'seatCapacity_4_to_6',
#        'seatCapacity_above_6', 'Brand_new_vehicles', 'Pre-owned_vehicles',
#        'category_Non-Transport', 'category_Transport', 'Mmm', 'quarter',
#        'fiscal_year'],
#       dtype='object')

# %%
df10["total1"] = df10['vehicleClass_MotorCycle']+df10['vehicleClass_MotorCar']+ df10['vehicleClass_AutoRickshaw']+ df10['vehicleClass_Agriculture']+ df10[ 'vehicleClass_others']

# %%
df10
# Out:
#                    district  vehicleClass_MotorCycle  vehicleClass_MotorCar  \
# 0                 Hyderabad                   206819                  51447
# 1                Rangareddy                   154186                  71832
# 2        Medchal_Malkajgiri                   164626                  61071
# 3                Sangareddy                    40784                  14565
# 4                   Khammam                    27385                   5880
# 5                  Nalgonda                    27942                   4927
# 6                 Nizamabad                    28105                   5824
# 7                Karimnagar                    19411                   4818
# 8                 Vikarabad                    23116                   5211
# 9                  Suryapet                    19165                   3038
# 10             Mahabubnagar                    17977                   3300
# ...

# %%
df10.sort_values("total",ascending=False,ignore_index=True,inplace = True)

# %%
df10
# Out:
#                    district  vehicleClass_MotorCycle  vehicleClass_MotorCar  \
# 0                 Hyderabad                   206819                  51447
# 1                Rangareddy                   154186                  71832
# 2        Medchal_Malkajgiri                   164626                  61071
# 3                Sangareddy                    40784                  14565
# 4                   Khammam                    27385                   5880
# 5                  Nalgonda                    27942                   4927
# 6                 Nizamabad                    28105                   5824
# 7                Karimnagar                    19411                   4818
# 8                 Vikarabad                    23116                   5211
# 9                  Suryapet                    19165                   3038
# 10             Mahabubnagar                    17977                   3300
# ...

# %%
df10.drop("total1",axis = 1,inplace = True)

# %%
df10
# Out:
#                    district  vehicleClass_MotorCycle  vehicleClass_MotorCar  \
# 0                 Hyderabad                   206819                  51447
# 1                Rangareddy                   154186                  71832
# 2        Medchal_Malkajgiri                   164626                  61071
# 3                Sangareddy                    40784                  14565
# 4                   Khammam                    27385                   5880
# 5                  Nalgonda                    27942                   4927
# 6                 Nizamabad                    28105                   5824
# 7                Karimnagar                    19411                   4818
# 8                 Vikarabad                    23116                   5211
# 9                  Suryapet                    19165                   3038
# 10             Mahabubnagar                    17977                   3300
# ...

# %%
df12=df[df['fiscal_year']>=2021]

# %%
df12
# Out:
#      dist_code              district       month  fuel_type_petrol  \
# 720       19_1              Adilabad  2021-04-01              1554
# 721       22_2  Bhadradri Kothagudem  2021-04-01              2697
# 722       16_1             Hyderabad  2021-04-01             17679
# 723       20_2               Jagtial  2021-04-01              1858
# 724       21_3               Jangoan  2021-04-01               990
# ...        ...                   ...         ...               ...
# 1435      23_2              Suryapet  2023-03-01              2013
# 1436      15_3             Vikarabad  2023-03-01              3088
# 1437      14_4            Wanaparthy  2023-03-01               996
# 1438      21_2              Warangal  2023-03-01              1832
# 1439      23_3   Yadadri Bhuvanagiri  2023-03-01              1659
#
#       fuel_type_diesel  fuel_type_electric  fuel_type_others  \
# 720                123                   2                 2
# ...

# %%
df12.groupby("district")[["fuel_type_petrol","fuel_type_diesel","fuel_type_electric","fuel_type_others"]].sum().reset_index()
# Out:
#                    district  fuel_type_petrol  fuel_type_diesel  \
# 0                  Adilabad             27804              4790
# 1      Bhadradri Kothagudem             46981             11451
# 2                 Hyderabad            459983             41214
# 3                   Jagtial             39781              5133
# 4                   Jangoan             23363              5616
# 5   Jayashankar Bhupalpally             26062              7073
# 6          Jogulamba Gadwal             25150              4645
# 7                 Kamareddy             43098              6226
# 8                Karimnagar             53648             15678
# 9                   Khammam             73360             16088
# 10    Kumurambheem Asifabad             16891              3557
# 11              Mahabubabad             30910              7357
# 12             Mahabubnagar             51618             10819
# 13               Mancherial             32147              6077
# ...
